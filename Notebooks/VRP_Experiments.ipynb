# %%
# D-Wave Leap Authentication
import os
from dwave.cloud import Client

def setup_dwave_config():
    """
    Setup D-Wave configuration for Leap access.
    Make sure you have your API token set up.
    """
    # Option 1: Set environment variable
    # os.environ['DWAVE_API_TOKEN'] = 'your_api_token_here'

    # Option 2: Use dwave config file (recommended)
    # Run: dwave config create in terminal to set up interactively

    # Test connection
    try:
        with Client.from_config() as client:
            print("✓ Successfully connected to D-Wave Leap")
            return True
    except Exception as e:
        print(f"✗ Connection failed: {e}")
        print("Please set up your D-Wave API token using 'dwave config create'")
        return False

# %%
# Test D-Wave connection
setup_dwave_config()
# Out:
# ✗ Connection failed: API token not defined
# Please set up your D-Wave API token using 'dwave config create'
# False

# %%
# ==============================================================================
# SETUP AND INSTALLATIONS
# ==============================================================================
print("--- Installing D-Wave libraries... ---")
# %pip install dwave-ocean-sdk --upgrade -q

# from google.colab import drive
# import sys, math

# print("\n--- Mounting Google Drive and setting up project path... ---")
# drive.mount('/content/drive', force_remount=True)

# # IMPORTANT: Make sure your project files are in this folder on your Google Drive
# project_path = '/content/drive/MyDrive/qintern-vrp/New-VRP'

# # Add the project path to the system's Python path so it can find your modules
# if project_path not in sys.path:
#     sys.path.append(project_path)
# print(f"Project path '{project_path}' added to system path.")
# Out:
# --- Installing D-Wave libraries... ---
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 51.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 15.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 76.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 kB 10.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 82.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 63.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 14.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.9/116.9 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 84.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.3/239.3 kB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.9 MB/s eta 0:00:00

# %%
# ==============================================================================
# MAIN EXPERIMENT SCRIPT
# Runs a predefined list of experiments to systematically verify solver performance.
# ==============================================================================
import numpy as np
import time
import math
import pandas as pd

from input import read_solomon
from vrp_problem import VRPProblem
from vrp_solvers import FullQuboSolver, AveragePartitionSolver

print("\n\n--- Starting VRP Solver Experiment Suite ---")

# ==============================================================================
# EXPERIMENT CONFIGURATION
# ==============================================================================
SOLOMON_FILE_PATH = 'c101.txt' # Adjust this path as needed
LIMIT_RADIUS = 1

# ==============================================================================
# This list is designed to replicate every FQS and APS test case from
# Table 3 of the Borowski, Gora, et al. paper.
# NOTE: The customer data is drawn from 'c101.txt', which differs from the
# paper's custom dataset. Expect different cost results, but look for
# similar performance *trends* between FQS and APS.
# ==============================================================================
experiments = [
    # --- "small" test cases from paper's Table 3 ---
    {'name': 'small-0 (2 cust, 1 veh)', 'customers': 2, 'vehicles': 1},
    {'name': 'small-0 (2 cust, 2 veh)', 'customers': 2, 'vehicles': 2},

    {'name': 'small-1 (2 cust, 1 veh)', 'customers': 2, 'vehicles': 1},
    {'name': 'small-1 (2 cust, 2 veh)', 'customers': 2, 'vehicles': 2},
    {'name': 'small-1 (2 cust, 3 veh)', 'customers': 2, 'vehicles': 3},

    {'name': 'small-2 (2 cust, 1 veh)', 'customers': 2, 'vehicles': 1},
    {'name': 'small-2 (2 cust, 2 veh)', 'customers': 2, 'vehicles': 2},
    {'name': 'small-2 (2 cust, 3 veh)', 'customers': 2, 'vehicles': 3},

    {'name': 'small-3 (1 cust, 1 veh)', 'customers': 1, 'vehicles': 1},
    {'name': 'small-3 (1 cust, 2 veh)', 'customers': 1, 'vehicles': 2},
    {'name': 'small-3 (1 cust, 3 veh)', 'customers': 1, 'vehicles': 3},

    {'name': 'small-4 (2 cust, 1 veh)', 'customers': 2, 'vehicles': 1},
    {'name': 'small-4 (2 cust, 2 veh)', 'customers': 2, 'vehicles': 2},
    {'name': 'small-4 (2 cust, 3 veh)', 'customers': 2, 'vehicles': 3},

    {'name': 'small-5 (5 cust, 1 veh)', 'customers': 5, 'vehicles': 1},
    {'name': 'small-5 (5 cust, 2 veh)', 'customers': 5, 'vehicles': 2},
    {'name': 'small-5 (5 cust, 3 veh)', 'customers': 5, 'vehicles': 3},

    {'name': 'small-6 (6 cust, 1 veh)', 'customers': 6, 'vehicles': 1},
    {'name': 'small-6 (6 cust, 2 veh)', 'customers': 6, 'vehicles': 2},
    {'name': 'small-6 (6 cust, 3 veh)', 'customers': 6, 'vehicles': 3},

    {'name': 'small-7 (5 cust, 1 veh)', 'customers': 5, 'vehicles': 1},
    {'name': 'small-7 (5 cust, 2 veh)', 'customers': 5, 'vehicles': 2},
    {'name': 'small-7 (5 cust, 3 veh)', 'customers': 5, 'vehicles': 3},

    {'name': 'small-8 (4 cust, 1 veh)', 'customers': 4, 'vehicles': 1},
    {'name': 'small-8 (4 cust, 2 veh)', 'customers': 4, 'vehicles': 2},
    {'name': 'small-8 (4 cust, 3 veh)', 'customers': 4, 'vehicles': 3},

    {'name': 'small-9 (6 cust, 1 veh)', 'customers': 6, 'vehicles': 1},
    {'name': 'small-9 (6 cust, 2 veh)', 'customers': 6, 'vehicles': 2},
    {'name': 'small-9 (6 cust, 3 veh)', 'customers': 6, 'vehicles': 3},

    # --- "medium" test cases from paper's Table 3 ---
    {'name': 'medium-0 (20 cust, 1 veh)', 'customers': 20, 'vehicles': 1},
    {'name': 'medium-0 (20 cust, 2 veh)', 'customers': 20, 'vehicles': 2},
    {'name': 'medium-0 (20 cust, 3 veh)', 'customers': 20, 'vehicles': 3},

    {'name': 'medium-1 (26 cust, 1 veh)', 'customers': 26, 'vehicles': 1},
    {'name': 'medium-1 (26 cust, 2 veh)', 'customers': 26, 'vehicles': 2},
    {'name': 'medium-1 (26 cust, 3 veh)', 'customers': 26, 'vehicles': 3},

    {'name': 'medium-2 (27 cust, 1 veh)', 'customers': 27, 'vehicles': 1},
    {'name': 'medium-2 (27 cust, 2 veh)', 'customers': 27, 'vehicles': 2},
    {'name': 'medium-2 (27 cust, 3 veh)', 'customers': 27, 'vehicles': 3},

    {'name': 'medium-3 (24 cust, 1 veh)', 'customers': 24, 'vehicles': 1},
    {'name': 'medium-3 (24 cust, 2 veh)', 'customers': 24, 'vehicles': 2},
    {'name': 'medium-3 (24 cust, 3 veh)', 'customers': 24, 'vehicles': 3},

    {'name': 'medium-4 (25 cust, 1 veh)', 'customers': 25, 'vehicles': 1},
    {'name': 'medium-4 (25 cust, 2 veh)', 'customers': 25, 'vehicles': 2},
    {'name': 'medium-4 (25 cust, 3 veh)', 'customers': 25, 'vehicles': 3},

    {'name': 'medium-5 (25 cust, 1 veh)', 'customers': 25, 'vehicles': 1},
    {'name': 'medium-5 (25 cust, 2 veh)', 'customers': 25, 'vehicles': 2},
    {'name': 'medium-5 (25 cust, 3 veh)', 'customers': 25, 'vehicles': 3},

    {'name': 'medium-6 (20 cust, 1 veh)', 'customers': 20, 'vehicles': 1},
    {'name': 'medium-6 (20 cust, 2 veh)', 'customers': 20, 'vehicles': 2},
    {'name': 'medium-6 (20 cust, 3 veh)', 'customers': 20, 'vehicles': 3},

    {'name': 'medium-7 (14 cust, 1 veh)', 'customers': 14, 'vehicles': 1},
    {'name': 'medium-7 (14 cust, 2 veh)', 'customers': 14, 'vehicles': 2},
    {'name': 'medium-7 (14 cust, 3 veh)', 'customers': 14, 'vehicles': 3},

    {'name': 'medium-8 (17 cust, 1 veh)', 'customers': 17, 'vehicles': 1},
    {'name': 'medium-8 (17 cust, 2 veh)', 'customers': 17, 'vehicles': 2},
    {'name': 'medium-8 (17 cust, 3 veh)', 'customers': 17, 'vehicles': 3},

    {'name': 'medium-9 (15 cust, 1 veh)', 'customers': 15, 'vehicles': 1},
    {'name': 'medium-9 (15 cust, 2 veh)', 'customers': 15, 'vehicles': 2},
    {'name': 'medium-9 (15 cust, 3 veh)', 'customers': 15, 'vehicles': 3},
]

# This list will store the summary of each experiment for the final table.
all_results = []

# ==============================================================================
# MAIN EXPERIMENT LOOP
# ==============================================================================
for test_config in experiments:

    NUM_CUSTOMERS = test_config['customers']
    NUM_VEHICLES = test_config['vehicles']

    print("\n\n" + "#"*70)
    print(f"###   STARTING TEST: {test_config['name']} ({NUM_CUSTOMERS} Customers, {NUM_VEHICLES} Vehicles)   ###")
    print("#"*70)

    # --- DATA LOADING AND PROBLEM SETUP ---
    print("\n--- Preparing the Vehicle Routing Problem ---")

    problem_data = read_solomon(SOLOMON_FILE_PATH, NUM_CUSTOMERS)
    vehicle_capacity = problem_data['capacities'][0]
    problem_data['capacities'] = np.array([vehicle_capacity] * NUM_VEHICLES)

    problem = VRPProblem(
        sources=problem_data['sources'],
        costs=problem_data['costs'],
        time_costs=problem_data['time_costs'],
        capacities=problem_data['capacities'],
        dests=problem_data['dests'],
        weights=problem_data['weights']
    )
    print(f"Problem created successfully for {len(problem.dests)} customers and {len(problem.capacities)} vehicles.")

    # --- QUBO FORMULATION PARAMETERS ---
    order_const = 1.0
    A1 = 1.0
    A2 = 10**7 # Using the exact (large) penalty from the paper
    print(f"\\nQUBO Parameters: A1 (objective) = {A1}, A2 (constraints) = {A2}")


    # --- EXPERIMENT 1 - FULL QUBO SOLVER (FQS) ---
    print("\n" + "="*60)
    print("--- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---")
    print("="*60)

    fqs_solver = FullQuboSolver(problem)
    print("Solving with classical Simulated Annealing...")
    start_time_fqs = time.time()
    fqs_solution = fqs_solver.solve(A1, A2, solver_type='simulated')
    end_time_fqs = time.time()
    fqs_run_time = end_time_fqs - start_time_fqs

    print("\n--- FQS RESULTS ---")
    print(f"Solver run time: {fqs_run_time:.2f} seconds")
    fqs_solution.description()
    fqs_cost = fqs_solution.total_cost()
    fqs_valid = fqs_solution.check()

    # --- EXPERIMENT 2 - AVERAGE PARTITION SOLVER (APS) ---
    print("\n" + "="*60)
    print("--- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---")
    print("="*60)

    aps_solver = AveragePartitionSolver(problem)
    print("Solving with classical Simulated Annealing...")
    start_time_aps = time.time()
    aps_solution = aps_solver.solve(A1, A2, solver_type='simulated', limit_radius=LIMIT_RADIUS)
    end_time_aps = time.time()
    aps_run_time = end_time_aps - start_time_aps

    print("\n--- APS RESULTS ---")
    print(f"Solver run time: {aps_run_time:.2f} seconds")
    aps_solution.description()
    aps_cost = aps_solution.total_cost()
    aps_valid = aps_solution.check()

    # --- STORE RESULTS FOR THIS TEST CONFIGURATION ---
    result_summary = {
        'Test Name': test_config['name'],
        'Customers': NUM_CUSTOMERS,
        'Vehicles': NUM_VEHICLES,
        'FQS Valid': '✅' if fqs_valid else '❌',
        'FQS Cost': f"{fqs_cost:.2f}",
        'FQS Time (s)': f"{fqs_run_time:.2f}",
        'APS Valid': '✅' if aps_valid else '❌',
        'APS Cost': f"{aps_cost:.2f}",
        'APS Time (s)': f"{aps_run_time:.2f}"
    }
    all_results.append(result_summary)


# ==============================================================================
# FINAL SUMMARY OF ALL EXPERIMENTS
# ==============================================================================
print("\n\n" + "#"*70)
print("###                  FINAL SUMMARY OF ALL EXPERIMENTS                  ###")
print("#"*70)

# Use pandas to create and display a clean table
df_results = pd.DataFrame(all_results)
print(df_results.to_string())
# Out:
# --- Starting VRP Solver Experiment Suite ---
#
#
# ######################################################################
# ###   STARTING TEST: small-0 (2 cust, 1 veh) (2 Customers, 1 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 2 customers and 1 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 2 -> 0
#
# Total Cost: 41.30
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 2 -> 1 -> 0
#
# Total Cost: 41.30
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-0 (2 cust, 2 veh) (2 Customers, 2 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 2 customers and 2 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 2 -> 0
#   Vehicle 1: 0 -> 1 -> 0
#
# Total Cost: 78.59
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 2 -> 0
#   Vehicle 1: 0 -> 1 -> 0
#
# Total Cost: 78.59
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-1 (2 cust, 1 veh) (2 Customers, 1 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 2 customers and 1 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 2 -> 1 -> 0
#
# Total Cost: 41.30
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 2 -> 1 -> 0
#
# Total Cost: 41.30
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-1 (2 cust, 2 veh) (2 Customers, 2 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 2 customers and 2 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 0
#   Vehicle 1: 0 -> 2 -> 0
#
# Total Cost: 78.59
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 0
#   Vehicle 1: 0 -> 2 -> 0
#
# Total Cost: 78.59
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-1 (2 cust, 3 veh) (2 Customers, 3 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 2 customers and 3 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.01 seconds
# Solution Routes:
#   Vehicle 0: Not used
#   Vehicle 1: 0 -> 1 -> 0
#   Vehicle 2: 0 -> 2 -> 0
#
# Total Cost: 78.59
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.01 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 2 -> 0
#   Vehicle 1: Not used
#   Vehicle 2: 0 -> 1 -> 0
#
# Total Cost: 78.59
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-2 (2 cust, 1 veh) (2 Customers, 1 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 2 customers and 1 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 2 -> 1 -> 0
#
# Total Cost: 41.30
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 2 -> 1 -> 0
#
# Total Cost: 41.30
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-2 (2 cust, 2 veh) (2 Customers, 2 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 2 customers and 2 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 0
#   Vehicle 1: 0 -> 2 -> 0
#
# Total Cost: 78.59
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 2 -> 0
#   Vehicle 1: 0 -> 1 -> 0
#
# Total Cost: 78.59
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-2 (2 cust, 3 veh) (2 Customers, 3 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 2 customers and 3 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.01 seconds
# Solution Routes:
#   Vehicle 0: Not used
#   Vehicle 1: 0 -> 2 -> 0
#   Vehicle 2: 0 -> 1 -> 0
#
# Total Cost: 78.59
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.01 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 2 -> 0
#   Vehicle 1: 0 -> 1 -> 0
#   Vehicle 2: Not used
#
# Total Cost: 78.59
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-3 (1 cust, 1 veh) (1 Customers, 1 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 1 customers and 1 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 0
#
# Total Cost: 37.36
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 0
#
# Total Cost: 37.36
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-3 (1 cust, 2 veh) (1 Customers, 2 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 1 customers and 2 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 0
#   Vehicle 1: Not used
#
# Total Cost: 37.36
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 0
#   Vehicle 1: Not used
#
# Total Cost: 37.36
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-3 (1 cust, 3 veh) (1 Customers, 3 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 1 customers and 3 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 0
#   Vehicle 1: Not used
#   Vehicle 2: Not used
#
# Total Cost: 37.36
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.01 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 0
#   Vehicle 1: Not used
#   Vehicle 2: Not used
#
# Total Cost: 37.36
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-4 (2 cust, 1 veh) (2 Customers, 1 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 2 customers and 1 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 2 -> 1 -> 0
#
# Total Cost: 41.30
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 2 -> 1 -> 0
#
# Total Cost: 41.30
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-4 (2 cust, 2 veh) (2 Customers, 2 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 2 customers and 2 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 2 -> 0
#   Vehicle 1: 0 -> 1 -> 0
#
# Total Cost: 78.59
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.00 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 0
#   Vehicle 1: 0 -> 2 -> 0
#
# Total Cost: 78.59
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-4 (2 cust, 3 veh) (2 Customers, 3 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 2 customers and 3 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.01 seconds
# Solution Routes:
#   Vehicle 0: Not used
#   Vehicle 1: 0 -> 2 -> 0
#   Vehicle 2: 0 -> 1 -> 0
#
# Total Cost: 78.59
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.01 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 2 -> 0
#   Vehicle 1: 0 -> 1 -> 0
#   Vehicle 2: Not used
#
# Total Cost: 78.59
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-5 (5 cust, 1 veh) (5 Customers, 1 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 5 customers and 1 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.01 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 2 -> 4 -> 3 -> 5 -> 0
#
# Total Cost: 42.42
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.01 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 4 -> 2 -> 3 -> 5 -> 0
#
# Total Cost: 46.42
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-5 (5 cust, 2 veh) (5 Customers, 2 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 5 customers and 2 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.03 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 2 -> 3 -> 0
#   Vehicle 1: 0 -> 4 -> 5 -> 0
#
# Total Cost: 78.05
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.02 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 3 -> 4 -> 5 -> 0
#   Vehicle 1: 0 -> 2 -> 1 -> 0
#
# Total Cost: 77.55
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-5 (5 cust, 3 veh) (5 Customers, 3 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 5 customers and 3 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.05 seconds
# Solution Routes:
#   Vehicle 0: Not used
#   Vehicle 1: 0 -> 3 -> 4 -> 0
#   Vehicle 2: 0 -> 2 -> 5 -> 1 -> 0
#
# Total Cost: 85.61
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.02 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 2 -> 0
#   Vehicle 1: 0 -> 1 -> 3 -> 0
#   Vehicle 2: 0 -> 4 -> 5 -> 0
#
# Total Cost: 115.89
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-6 (6 cust, 1 veh) (6 Customers, 1 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 6 customers and 1 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.02 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 5 -> 6 -> 2 -> 1 -> 4 -> 3 -> 0
#
# Total Cost: 47.83
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.02 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 3 -> 1 -> 2 -> 4 -> 6 -> 5 -> 0
#
# Total Cost: 47.18
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-6 (6 cust, 2 veh) (6 Customers, 2 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 6 customers and 2 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.04 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 5 -> 6 -> 0
#   Vehicle 1: 0 -> 2 -> 1 -> 4 -> 3 -> 0
#
# Total Cost: 82.34
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.03 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 3 -> 5 -> 0
#   Vehicle 1: 0 -> 4 -> 2 -> 6 -> 0
#
# Total Cost: 84.24
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-6 (6 cust, 3 veh) (6 Customers, 3 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 6 customers and 3 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.07 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 3 -> 4 -> 0
#   Vehicle 1: 0 -> 5 -> 1 -> 2 -> 6 -> 0
#   Vehicle 2: Not used
#
# Total Cost: 81.71
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.03 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 6 -> 2 -> 0
#   Vehicle 1: 0 -> 1 -> 4 -> 0
#   Vehicle 2: 0 -> 3 -> 5 -> 0
#
# Total Cost: 116.76
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-7 (5 cust, 1 veh) (5 Customers, 1 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 5 customers and 1 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.01 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 5 -> 3 -> 4 -> 2 -> 1 -> 0
#
# Total Cost: 42.42
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.01 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 4 -> 3 -> 1 -> 2 -> 5 -> 0
#
# Total Cost: 46.68
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-7 (5 cust, 2 veh) (5 Customers, 2 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 5 customers and 2 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.03 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 0
#   Vehicle 1: 0 -> 4 -> 2 -> 3 -> 5 -> 0
#
# Total Cost: 80.21
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.02 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 2 -> 3 -> 0
#   Vehicle 1: 0 -> 1 -> 4 -> 5 -> 0
#
# Total Cost: 81.55
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-7 (5 cust, 3 veh) (5 Customers, 3 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 5 customers and 3 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.04 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 2 -> 4 -> 0
#   Vehicle 1: Not used
#   Vehicle 2: 0 -> 5 -> 3 -> 0
#
# Total Cost: 74.66
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.02 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 2 -> 1 -> 0
#   Vehicle 1: 0 -> 4 -> 0
#   Vehicle 2: 0 -> 5 -> 3 -> 0
#
# Total Cost: 109.78
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-8 (4 cust, 1 veh) (4 Customers, 1 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 4 customers and 1 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.01 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 3 -> 4 -> 2 -> 1 -> 0
#
# Total Cost: 42.41
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.01 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 2 -> 4 -> 3 -> 0
#
# Total Cost: 42.41
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-8 (4 cust, 2 veh) (4 Customers, 2 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 4 customers and 2 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.02 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 4 -> 1 -> 3 -> 0
#   Vehicle 1: 0 -> 2 -> 0
#
# Total Cost: 82.07
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.01 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 3 -> 1 -> 0
#   Vehicle 1: 0 -> 4 -> 2 -> 0
#
# Total Cost: 80.74
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-8 (4 cust, 3 veh) (4 Customers, 3 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 4 customers and 3 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.03 seconds
# Solution Routes:
#   Vehicle 0: Not used
#   Vehicle 1: 0 -> 4 -> 2 -> 0
#   Vehicle 2: 0 -> 1 -> 3 -> 0
#
# Total Cost: 80.74
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.02 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 2 -> 4 -> 0
#   Vehicle 1: Not used
#   Vehicle 2: 0 -> 3 -> 1 -> 0
#
# Total Cost: 80.74
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-9 (6 cust, 1 veh) (6 Customers, 1 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 6 customers and 1 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.02 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 3 -> 2 -> 1 -> 4 -> 6 -> 5 -> 0
#
# Total Cost: 47.97
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.02 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 3 -> 5 -> 1 -> 2 -> 4 -> 6 -> 0
#
# Total Cost: 48.21
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-9 (6 cust, 2 veh) (6 Customers, 2 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 6 customers and 2 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.04 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 4 -> 6 -> 0
#   Vehicle 1: 0 -> 2 -> 3 -> 5 -> 1 -> 0
#
# Total Cost: 88.89
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.03 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 3 -> 5 -> 2 -> 0
#   Vehicle 1: 0 -> 4 -> 6 -> 1 -> 0
#
# Total Cost: 87.70
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: small-9 (6 cust, 3 veh) (6 Customers, 3 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 6 customers and 3 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.07 seconds
# Solution Routes:
#   Vehicle 0: Not used
#   Vehicle 1: 0 -> 6 -> 5 -> 2 -> 0
#   Vehicle 2: 0 -> 1 -> 3 -> 4 -> 0
#
# Total Cost: 92.32
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.03 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 4 -> 3 -> 0
#   Vehicle 1: 0 -> 5 -> 6 -> 0
#   Vehicle 2: 0 -> 2 -> 1 -> 0
#
# Total Cost: 116.14
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: medium-0 (20 cust, 1 veh) (20 Customers, 1 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 20 customers and 1 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.33 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 4 -> 11 -> 14 -> 8 -> 10 -> 6 -> 12 -> 15 -> 19 -> 18 -> 13 -> 17 -> 1 -> 3 -> 7 -> 9 -> 20 -> 16 -> 2 -> 5 -> 0
#
# Total Cost: 274.61
# Warning: Vehicle 0 exceeds capacity. Load: 360.0, Capacity: 200
# Is Solution Valid: False
# Warning: Vehicle 0 exceeds capacity. Load: 360.0, Capacity: 200
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.33 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 5 -> 4 -> 14 -> 19 -> 1 -> 11 -> 10 -> 8 -> 9 -> 2 -> 6 -> 16 -> 20 -> 3 -> 7 -> 15 -> 18 -> 13 -> 12 -> 17 -> 0
#
# Total Cost: 294.50
# Warning: Vehicle 0 exceeds capacity. Load: 360.0, Capacity: 200
# Is Solution Valid: False
# Warning: Vehicle 0 exceeds capacity. Load: 360.0, Capacity: 200
#
#
# ######################################################################
# ###   STARTING TEST: medium-0 (20 cust, 2 veh) (20 Customers, 2 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 20 customers and 2 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.77 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 6 -> 5 -> 2 -> 4 -> 15 -> 13 -> 12 -> 19 -> 10 -> 8 -> 0
#   Vehicle 1: 0 -> 3 -> 20 -> 7 -> 11 -> 17 -> 16 -> 9 -> 18 -> 1 -> 14 -> 0
#
# Total Cost: 365.88
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.43 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 14 -> 16 -> 15 -> 18 -> 7 -> 20 -> 9 -> 12 -> 5 -> 1 -> 3 -> 0
#   Vehicle 1: 0 -> 17 -> 13 -> 6 -> 4 -> 10 -> 19 -> 11 -> 8 -> 2 -> 0
#
# Total Cost: 334.57
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: medium-0 (20 cust, 3 veh) (20 Customers, 3 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 20 customers and 3 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 1.78 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 9 -> 10 -> 2 -> 8 -> 5 -> 20 -> 1 -> 11 -> 12 -> 18 -> 0
#   Vehicle 1: 0 -> 3 -> 4 -> 19 -> 13 -> 0
#   Vehicle 2: 0 -> 17 -> 6 -> 15 -> 14 -> 16 -> 7 -> 0
#
# Total Cost: 386.19
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.39 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 8 -> 1 -> 10 -> 20 -> 0
#   Vehicle 1: 0 -> 18 -> 15 -> 13 -> 7 -> 4 -> 12 -> 2 -> 5 -> 0
#   Vehicle 2: 0 -> 11 -> 9 -> 6 -> 3 -> 19 -> 14 -> 17 -> 16 -> 0
#
# Total Cost: 331.79
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: medium-1 (26 cust, 1 veh) (26 Customers, 1 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 26 customers and 1 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.65 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 24 -> 21 -> 6 -> 4 -> 18 -> 14 -> 11 -> 16 -> 19 -> 17 -> 15 -> 8 -> 2 -> 12 -> 25 -> 23 -> 1 -> 7 -> 26 -> 3 -> 22 -> 20 -> 10 -> 9 -> 13 -> 5 -> 0
#
# Total Cost: 398.72
# Warning: Vehicle 0 exceeds capacity. Load: 470.0, Capacity: 200
# Is Solution Valid: False
# Warning: Vehicle 0 exceeds capacity. Load: 470.0, Capacity: 200
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.69 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 11 -> 5 -> 3 -> 25 -> 12 -> 14 -> 23 -> 4 -> 6 -> 20 -> 18 -> 7 -> 16 -> 17 -> 15 -> 10 -> 8 -> 2 -> 21 -> 22 -> 24 -> 26 -> 1 -> 13 -> 19 -> 9 -> 0
#
# Total Cost: 426.15
# Warning: Vehicle 0 exceeds capacity. Load: 470.0, Capacity: 200
# Is Solution Valid: False
# Warning: Vehicle 0 exceeds capacity. Load: 470.0, Capacity: 200
#
#
# ######################################################################
# ###   STARTING TEST: medium-1 (26 cust, 2 veh) (26 Customers, 2 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 26 customers and 2 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 1.59 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 6 -> 8 -> 13 -> 12 -> 20 -> 2 -> 9 -> 26 -> 24 -> 4 -> 1 -> 22 -> 0
#   Vehicle 1: 0 -> 21 -> 19 -> 16 -> 17 -> 14 -> 18 -> 23 -> 11 -> 5 -> 15 -> 10 -> 7 -> 3 -> 25 -> 0
#
# Total Cost: 425.69
# Warning: Vehicle 1 exceeds capacity. Load: 270.0, Capacity: 200
# Is Solution Valid: False
# Warning: Vehicle 1 exceeds capacity. Load: 270.0, Capacity: 200
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.78 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 22 -> 10 -> 9 -> 8 -> 14 -> 18 -> 19 -> 15 -> 20 -> 16 -> 12 -> 17 -> 0
#   Vehicle 1: 0 -> 21 -> 1 -> 24 -> 13 -> 5 -> 11 -> 2 -> 26 -> 25 -> 7 -> 6 -> 4 -> 3 -> 23 -> 0
#
# Total Cost: 410.15
# Warning: Vehicle 0 exceeds capacity. Load: 230.0, Capacity: 200
# Is Solution Valid: False
# Warning: Vehicle 0 exceeds capacity. Load: 230.0, Capacity: 200
#
#
# ######################################################################
# ###   STARTING TEST: medium-1 (26 cust, 3 veh) (26 Customers, 3 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 26 customers and 3 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 2.84 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 5 -> 16 -> 19 -> 25 -> 24 -> 17 -> 26 -> 0
#   Vehicle 1: 0 -> 21 -> 7 -> 23 -> 15 -> 13 -> 22 -> 20 -> 12 -> 10 -> 0
#   Vehicle 2: 0 -> 14 -> 1 -> 8 -> 9 -> 6 -> 4 -> 3 -> 11 -> 18 -> 2 -> 0
#
# Total Cost: 485.09
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.75 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 25 -> 12 -> 26 -> 22 -> 5 -> 20 -> 6 -> 3 -> 23 -> 0
#   Vehicle 1: 0 -> 9 -> 14 -> 13 -> 17 -> 4 -> 10 -> 19 -> 16 -> 15 -> 18 -> 0
#   Vehicle 2: 0 -> 1 -> 24 -> 21 -> 2 -> 8 -> 7 -> 11 -> 0
#
# Total Cost: 453.78
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: medium-2 (27 cust, 1 veh) (27 Customers, 1 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 27 customers and 1 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.73 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 22 -> 16 -> 15 -> 26 -> 19 -> 12 -> 10 -> 3 -> 11 -> 17 -> 1 -> 2 -> 8 -> 14 -> 13 -> 25 -> 9 -> 21 -> 4 -> 7 -> 6 -> 5 -> 18 -> 27 -> 24 -> 20 -> 23 -> 0
#
# Total Cost: 414.11
# Warning: Vehicle 0 exceeds capacity. Load: 480.0, Capacity: 200
# Is Solution Valid: False
# Warning: Vehicle 0 exceeds capacity. Load: 480.0, Capacity: 200
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.76 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 2 -> 23 -> 5 -> 8 -> 16 -> 12 -> 19 -> 11 -> 7 -> 1 -> 18 -> 15 -> 13 -> 17 -> 27 -> 6 -> 4 -> 26 -> 22 -> 25 -> 20 -> 14 -> 10 -> 21 -> 3 -> 9 -> 24 -> 0
#
# Total Cost: 408.32
# Warning: Vehicle 0 exceeds capacity. Load: 480.0, Capacity: 200
# Is Solution Valid: False
# Warning: Vehicle 0 exceeds capacity. Load: 480.0, Capacity: 200
#
#
# ######################################################################
# ###   STARTING TEST: medium-2 (27 cust, 2 veh) (27 Customers, 2 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 27 customers and 2 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 2.39 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 21 -> 3 -> 23 -> 13 -> 9 -> 1 -> 17 -> 20 -> 26 -> 27 -> 15 -> 4 -> 5 -> 0
#   Vehicle 1: 0 -> 2 -> 6 -> 8 -> 18 -> 14 -> 12 -> 25 -> 7 -> 10 -> 22 -> 24 -> 11 -> 19 -> 16 -> 0
#
# Total Cost: 465.67
# Warning: Vehicle 1 exceeds capacity. Load: 280.0, Capacity: 200
# Is Solution Valid: False
# Warning: Vehicle 1 exceeds capacity. Load: 280.0, Capacity: 200
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.82 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 22 -> 1 -> 23 -> 25 -> 12 -> 9 -> 3 -> 4 -> 14 -> 16 -> 7 -> 11 -> 8 -> 6 -> 0
#   Vehicle 1: 0 -> 17 -> 13 -> 20 -> 2 -> 15 -> 19 -> 21 -> 18 -> 24 -> 10 -> 5 -> 27 -> 26 -> 0
#
# Total Cost: 482.73
# Warning: Vehicle 0 exceeds capacity. Load: 250.0, Capacity: 200
# Is Solution Valid: False
# Warning: Vehicle 0 exceeds capacity. Load: 250.0, Capacity: 200
#
#
# ######################################################################
# ###   STARTING TEST: medium-2 (27 cust, 3 veh) (27 Customers, 3 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 27 customers and 3 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 3.34 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 9 -> 6 -> 10 -> 23 -> 25 -> 26 -> 17 -> 15 -> 13 -> 3 -> 0
#   Vehicle 1: 0 -> 27 -> 18 -> 4 -> 20 -> 14 -> 11 -> 5 -> 7 -> 19 -> 16 -> 8 -> 0
#   Vehicle 2: 0 -> 22 -> 12 -> 2 -> 21 -> 1 -> 24 -> 0
#
# Total Cost: 512.44
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# ...
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.17 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 5 -> 13 -> 6 -> 2 -> 0
#   Vehicle 1: 0 -> 12 -> 4 -> 10 -> 3 -> 1 -> 0
#   Vehicle 2: 0 -> 7 -> 14 -> 8 -> 9 -> 11 -> 0
#
# Total Cost: 271.20
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: medium-8 (17 cust, 1 veh) (17 Customers, 1 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 17 customers and 1 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.21 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 17 -> 8 -> 12 -> 13 -> 15 -> 5 -> 1 -> 3 -> 7 -> 2 -> 11 -> 9 -> 16 -> 14 -> 4 -> 6 -> 10 -> 0
#
# Total Cost: 224.32
# Warning: Vehicle 0 exceeds capacity. Load: 320.0, Capacity: 200
# Is Solution Valid: False
# Warning: Vehicle 0 exceeds capacity. Load: 320.0, Capacity: 200
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.24 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 2 -> 17 -> 10 -> 6 -> 16 -> 15 -> 12 -> 13 -> 9 -> 8 -> 5 -> 11 -> 4 -> 14 -> 7 -> 3 -> 0
#
# Total Cost: 230.77
# Warning: Vehicle 0 exceeds capacity. Load: 320.0, Capacity: 200
# Is Solution Valid: False
# Warning: Vehicle 0 exceeds capacity. Load: 320.0, Capacity: 200
#
#
# ######################################################################
# ###   STARTING TEST: medium-8 (17 cust, 2 veh) (17 Customers, 2 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 17 customers and 2 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.50 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 3 -> 5 -> 1 -> 15 -> 10 -> 17 -> 9 -> 16 -> 14 -> 13 -> 0
#   Vehicle 1: 0 -> 2 -> 11 -> 12 -> 6 -> 4 -> 7 -> 8 -> 0
#
# Total Cost: 273.17
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.27 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 10 -> 5 -> 8 -> 4 -> 7 -> 9 -> 14 -> 16 -> 0
#   Vehicle 1: 0 -> 15 -> 13 -> 12 -> 11 -> 6 -> 17 -> 2 -> 3 -> 0
#
# Total Cost: 263.63
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: medium-8 (17 cust, 3 veh) (17 Customers, 3 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 17 customers and 3 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 1.37 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 7 -> 16 -> 6 -> 9 -> 10 -> 8 -> 0
#   Vehicle 1: 0 -> 17 -> 14 -> 2 -> 0
#   Vehicle 2: 0 -> 3 -> 11 -> 5 -> 12 -> 13 -> 15 -> 4 -> 0
#
# Total Cost: 315.41
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.27 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 2 -> 13 -> 15 -> 16 -> 12 -> 14 -> 0
#   Vehicle 1: 0 -> 6 -> 1 -> 5 -> 11 -> 8 -> 10 -> 0
#   Vehicle 2: 0 -> 7 -> 17 -> 4 -> 3 -> 9 -> 0
#
# Total Cost: 254.36
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: medium-9 (15 cust, 1 veh) (15 Customers, 1 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 15 customers and 1 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.14 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 2 -> 3 -> 4 -> 15 -> 13 -> 9 -> 11 -> 5 -> 6 -> 8 -> 14 -> 12 -> 7 -> 10 -> 0
#
# Total Cost: 165.14
# Warning: Vehicle 0 exceeds capacity. Load: 260.0, Capacity: 200
# Is Solution Valid: False
# Warning: Vehicle 0 exceeds capacity. Load: 260.0, Capacity: 200
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.17 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 6 -> 1 -> 4 -> 13 -> 12 -> 14 -> 15 -> 3 -> 9 -> 8 -> 2 -> 5 -> 10 -> 7 -> 11 -> 0
#
# Total Cost: 151.51
# Warning: Vehicle 0 exceeds capacity. Load: 260.0, Capacity: 200
# Is Solution Valid: False
# Warning: Vehicle 0 exceeds capacity. Load: 260.0, Capacity: 200
#
#
# ######################################################################
# ###   STARTING TEST: medium-9 (15 cust, 2 veh) (15 Customers, 2 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 15 customers and 2 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.37 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 1 -> 4 -> 2 -> 7 -> 6 -> 3 -> 8 -> 11 -> 10 -> 0
#   Vehicle 1: 0 -> 14 -> 12 -> 9 -> 13 -> 15 -> 5 -> 0
#
# Total Cost: 191.81
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.18 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 11 -> 4 -> 12 -> 13 -> 15 -> 14 -> 10 -> 0
#   Vehicle 1: 0 -> 8 -> 3 -> 5 -> 1 -> 2 -> 7 -> 6 -> 9 -> 0
#
# Total Cost: 173.32
# Is Solution Valid: True
#
#
# ######################################################################
# ###   STARTING TEST: medium-9 (15 cust, 3 veh) (15 Customers, 3 Vehicles)   ###
# ######################################################################
#
# --- Preparing the Vehicle Routing Problem ---
# Problem created successfully for 15 customers and 3 vehicles.
# \nQUBO Parameters: A1 (objective) = 1.0, A2 (constraints) = 10000000
#
# ============================================================
# --- RUNNING EXPERIMENT: FullQuboSolver (FQS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- FQS RESULTS ---
# Solver run time: 0.63 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 7 -> 4 -> 3 -> 15 -> 0
#   Vehicle 1: 0 -> 6 -> 11 -> 13 -> 10 -> 1 -> 8 -> 0
#   Vehicle 2: 0 -> 5 -> 12 -> 14 -> 9 -> 2 -> 0
#
# Total Cost: 266.33
# Is Solution Valid: True
#
# ============================================================
# --- RUNNING EXPERIMENT: AveragePartitionSolver (APS) ---
# ============================================================
# Solving with classical Simulated Annealing...
#
# --- APS RESULTS ---
# Solver run time: 0.18 seconds
# Solution Routes:
#   Vehicle 0: 0 -> 5 -> 4 -> 9 -> 12 -> 13 -> 2 -> 0
#   Vehicle 1: 0 -> 7 -> 6 -> 15 -> 14 -> 0
#   Vehicle 2: 0 -> 3 -> 10 -> 8 -> 1 -> 11 -> 0
#
# Total Cost: 247.04
# Is Solution Valid: True
#
#
# ######################################################################
# ###                  FINAL SUMMARY OF ALL EXPERIMENTS                  ###
# ######################################################################
#                     Test Name  Customers  Vehicles FQS Valid FQS Cost FQS Time (s) APS Valid APS Cost APS Time (s)
# 0     small-0 (2 cust, 1 veh)          2         1         ✅    41.30         0.00         ✅    41.30         0.00
# 1     small-0 (2 cust, 2 veh)          2         2         ✅    78.59         0.00         ✅    78.59         0.00
# 2     small-1 (2 cust, 1 veh)          2         1         ✅    41.30         0.00         ✅    41.30         0.00
# 3     small-1 (2 cust, 2 veh)          2         2         ✅    78.59         0.00         ✅    78.59         0.00
# 4     small-1 (2 cust, 3 veh)          2         3         ✅    78.59         0.01         ✅    78.59         0.01
# 5     small-2 (2 cust, 1 veh)          2         1         ✅    41.30         0.00         ✅    41.30         0.00
# 6     small-2 (2 cust, 2 veh)          2         2         ✅    78.59         0.00         ✅    78.59         0.00
# 7     small-2 (2 cust, 3 veh)          2         3         ✅    78.59         0.01         ✅    78.59         0.01
# 8     small-3 (1 cust, 1 veh)          1         1         ✅    37.36         0.00         ✅    37.36         0.00
# 9     small-3 (1 cust, 2 veh)          1         2         ✅    37.36         0.00         ✅    37.36         0.00
# 10    small-3 (1 cust, 3 veh)          1         3         ✅    37.36         0.00         ✅    37.36         0.01
# 11    small-4 (2 cust, 1 veh)          2         1         ✅    41.30         0.00         ✅    41.30         0.00
# 12    small-4 (2 cust, 2 veh)          2         2         ✅    78.59         0.00         ✅    78.59         0.00
# 13    small-4 (2 cust, 3 veh)          2         3         ✅    78.59         0.01         ✅    78.59         0.01
# 14    small-5 (5 cust, 1 veh)          5         1         ✅    42.42         0.01         ✅    46.42         0.01
# 15    small-5 (5 cust, 2 veh)          5         2         ✅    78.05         0.03         ✅    77.55         0.02
# 16    small-5 (5 cust, 3 veh)          5         3         ✅    85.61         0.05         ✅   115.89         0.02
# 17    small-6 (6 cust, 1 veh)          6         1         ✅    47.83         0.02         ✅    47.18         0.02
# 18    small-6 (6 cust, 2 veh)          6         2         ✅    82.34         0.04         ✅    84.24         0.03
# 19    small-6 (6 cust, 3 veh)          6         3         ✅    81.71         0.07         ✅   116.76         0.03
# 20    small-7 (5 cust, 1 veh)          5         1         ✅    42.42         0.01         ✅    46.68         0.01
# 21    small-7 (5 cust, 2 veh)          5         2         ✅    80.21         0.03         ✅    81.55         0.02
# 22    small-7 (5 cust, 3 veh)          5         3         ✅    74.66         0.04         ✅   109.78         0.02
# 23    small-8 (4 cust, 1 veh)          4         1         ✅    42.41         0.01         ✅    42.41         0.01
# 24    small-8 (4 cust, 2 veh)          4         2         ✅    82.07         0.02         ✅    80.74         0.01
# 25    small-8 (4 cust, 3 veh)          4         3         ✅    80.74         0.03         ✅    80.74         0.02
# 26    small-9 (6 cust, 1 veh)          6         1         ✅    47.97         0.02         ✅    48.21         0.02
# 27    small-9 (6 cust, 2 veh)          6         2         ✅    88.89         0.04         ✅    87.70         0.03
# 28    small-9 (6 cust, 3 veh)          6         3         ✅    92.32         0.07         ✅   116.14         0.03
# 29  medium-0 (20 cust, 1 veh)         20         1         ❌   274.61         0.33         ❌   294.50         0.33
# 30  medium-0 (20 cust, 2 veh)         20         2         ✅   365.88         0.77         ✅   334.57         0.43
# 31  medium-0 (20 cust, 3 veh)         20         3         ✅   386.19         1.78         ✅   331.79         0.39
# 32  medium-1 (26 cust, 1 veh)         26         1         ❌   398.72         0.65         ❌   426.15         0.69
# 33  medium-1 (26 cust, 2 veh)         26         2         ❌   425.69         1.59         ❌   410.15         0.78
# 34  medium-1 (26 cust, 3 veh)         26         3         ✅   485.09         2.84         ✅   453.78         0.75
# 35  medium-2 (27 cust, 1 veh)         27         1         ❌   414.11         0.73         ❌   408.32         0.76
# 36  medium-2 (27 cust, 2 veh)         27         2         ❌   465.67         2.39         ❌   482.73         0.82
# 37  medium-2 (27 cust, 3 veh)         27         3         ✅   512.44         3.34         ✅   505.91         0.89
# 38  medium-3 (24 cust, 1 veh)         24         1         ❌   353.15         0.53         ❌   390.39         0.55
# 39  medium-3 (24 cust, 2 veh)         24         2         ❌   454.77         1.28         ❌   328.30         0.58
# 40  medium-3 (24 cust, 3 veh)         24         3         ✅   461.53         2.81         ✅   413.23         0.59
# 41  medium-4 (25 cust, 1 veh)         25         1         ❌   394.45         0.60         ❌   392.54         0.61
# 42  medium-4 (25 cust, 2 veh)         25         2         ❌   466.88         1.44         ❌   424.80         0.66
# 43  medium-4 (25 cust, 3 veh)         25         3         ❌   511.99         2.56         ✅   397.36         0.73
# 44  medium-5 (25 cust, 1 veh)         25         1         ❌   403.47         0.58         ❌   399.10         0.63
# 45  medium-5 (25 cust, 2 veh)         25         2         ❌   376.20         1.75         ❌   407.31         0.89
# 46  medium-5 (25 cust, 3 veh)         25         3         ✅   563.23         2.69         ✅   440.95         0.74
# 47  medium-6 (20 cust, 1 veh)         20         1         ❌   271.57         0.32         ❌   295.29         0.34
# 48  medium-6 (20 cust, 2 veh)         20         2         ✅   317.38         0.79         ✅   321.85         0.36
# 49  medium-6 (20 cust, 3 veh)         20         3         ✅   382.37         1.34         ✅   385.69         0.39
# 50  medium-7 (14 cust, 1 veh)         14         1         ❌   148.44         0.12         ❌   162.34         0.13
# 51  medium-7 (14 cust, 2 veh)         14         2         ✅   193.87         0.31         ✅   165.90         0.14
# 52  medium-7 (14 cust, 3 veh)         14         3         ✅   223.45         0.52         ✅   271.20         0.17
# 53  medium-8 (17 cust, 1 veh)         17         1         ❌   224.32         0.21         ❌   230.77         0.24
# 54  medium-8 (17 cust, 2 veh)         17         2         ✅   273.17         0.50         ✅   263.63         0.27
# 55  medium-8 (17 cust, 3 veh)         17         3         ✅   315.41         1.37         ✅   254.36         0.27
# 56  medium-9 (15 cust, 1 veh)         15         1         ❌   165.14         0.14         ❌   151.51         0.17
# 57  medium-9 (15 cust, 2 veh)         15         2         ✅   191.81         0.37         ✅   173.32         0.18
# 58  medium-9 (15 cust, 3 veh)         15         3         ✅   266.33         0.63         ✅   247.04         0.18

# %%
# Testing all solver types

solver_types = ['simulated', 'exact', 'hybrid']  # Add 'qpu' if you have access

for solver_type in solver_types:
    print(f"\n=== Testing {solver_type} solver ===")
    try:
        # Use a small problem for testing
        test_problem = read_solomon(SOLOMON_FILE_PATH, 3)  # Only 3 customers right now
        # ... run your solver test here
        print(f"✓ {solver_type} solver working correctly")
    except Exception as e:
        print(f"✗ {solver_type} solver failed: {e}")
# Out:
# === Testing simulated solver ===
# ✓ simulated solver working correctly
#
# === Testing exact solver ===
# ✓ exact solver working correctly
#
# === Testing hybrid solver ===
# ✓ hybrid solver working correctly
